# %% [markdown]
# # Geração do modelo treinado

# %%
from class_experiment import Experimento

num_neurons = 32
params = {
    'env_id': 'CartPole-v1',
    'policy_kwargs': dict(net_arch=[num_neurons, num_neurons]),
    'seeds': [0],
    'timesteps': int(1e4),
}

teste = Experimento(params)
teste.treinamento()

# %%
from class_experiment import Experimento
from GeraPlots import main_pipeline
import torch
import gc

num_neurons = 32
env_id = 'CartPole-v1'
params = {
    'policy_kwargs': dict(net_arch=[num_neurons, num_neurons]),
    'timesteps': int(1e6),
    'directory': f'../data/groups/{env_id}_{num_neurons}',
    'net_init': 2
}

enviroment_list = [
    # 'Acrobot-v1',
    'BipedalWalker-v3',
    # 'CarRacing-v3',
    # 'CartPole-v1',
    # 'MountainCar-v0',
    # 'Pendulum-v1',
    # 'MountainCarContinuous-v0',
    # 'LunarLander-v3'
]


for enviroment in enviroment_list:
    for init in range(10):
        params['directory'] = f'../data/groups/{enviroment}_{num_neurons}_{init}'
        for seed in range(20):
            params['seeds'] = [seed]
            params['env_id'] = enviroment
            params['net_init'] = init
            Ensaio = None  # Inicializa como None
            try:
                Ensaio = Experimento(params)
                Ensaio.treinamento()
                gc.collect()            
            finally:
                # Cleanup crítico
                if Ensaio is not None:
                    if hasattr(Ensaio, 'train_env'):
                        Ensaio.train_env.close()
                    if hasattr(Ensaio, 'model'):
                        # Limpa buffer do modelo
                        if hasattr(Ensaio.model, 'rollout_buffer'):
                            del Ensaio.model.rollout_buffer
                        del Ensaio.model
                    del Ensaio
                if torch.cuda.is_available():
                    torch.cuda.empty_cache()
                gc.collect()            
        main_pipeline(params['directory'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Github/Dissertacao/.venv/lib/python3.10/site-packages/gymnasium/envs/box2d/bipedal_walker.py:15
#      14 try:
# ---> 15     import Box2D
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)
#      22         revoluteJointDef,
#      23     )
#
# ModuleNotFoundError: No module named 'Box2D'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[1], line 36
#      34 Ensaio = None  # Inicializa como None
#      35 try:
# ---> 36     Ensaio = Experimento(params)
#      37     Ensaio.treinamento()
#      38     gc.collect()
#
# File ~/Documents/Github/Dissertacao/src/class_experiment.py:236, in Experimento.__init__(self, params)
#     209 self.directory = criar_pasta(self.directory)
#     211 self._hyperparams = {
#     212     'learning_rate': self.learning_rate,
#     213     'n_steps': self.n_steps,
#    (...)
#     233     'device': self.device
#     234 }
# --> 236 self.train_env = Monitor(gymnasium.make(self.env_id))
#     238 #* Reprodutibilidade
#     239 torch.manual_seed(self.net_init)
#
# File ~/Documents/Github/Dissertacao/.venv/lib/python3.10/site-packages/gymnasium/envs/registration.py:696, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     693     env_creator = env_spec.entry_point
#     694 else:
#     695     # Assume it's a string
# --> 696     env_creator = load_env_creator(env_spec.entry_point)
#     698 # Determine if to use the rendering
#     699 render_modes: list[str] | None = None
#
# File ~/Documents/Github/Dissertacao/.venv/lib/python3.10/site-packages/gymnasium/envs/registration.py:544, in load_env_creator(name)
#     535 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     536
#     537 Args:
#    (...)
#     541     The environment constructor for the given environment name.
#     542 """
#     543 mod_name, attr_name = name.split(":")
# --> 544 mod = importlib.import_module(mod_name)
#     545 fn = getattr(mod, attr_name)
#     546 return fn
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:992, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Documents/Github/Dissertacao/.venv/lib/python3.10/site-packages/gymnasium/envs/box2d/__init__.py:1
# ----> 1 from gymnasium.envs.box2d.bipedal_walker import BipedalWalker, BipedalWalkerHardcore
#       2 from gymnasium.envs.box2d.car_racing import CarRacing
#       3 from gymnasium.envs.box2d.lunar_lander import LunarLander, LunarLanderContinuous
#
# File ~/Documents/Github/Dissertacao/.venv/lib/python3.10/site-packages/gymnasium/envs/box2d/bipedal_walker.py:25
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)
#      22         revoluteJointDef,
#      23     )
#      24 except ImportError as e:
# ---> 25     raise DependencyNotInstalled(
#      26         'Box2D is not installed, you can install it by run `pip install swig` followed by `pip install "gymnasium[box2d]"`'
#      27     ) from e
#      30 if TYPE_CHECKING:
#      31     import pygame
#
# DependencyNotInstalled: Box2D is not installed, you can install it by run `pip install swig` followed by `pip install "gymnasium[box2d]"`
